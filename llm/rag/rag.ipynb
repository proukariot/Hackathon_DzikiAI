# %%
import requests
# from sql_db.visit import Visit

SERVER_URL = "http://localhost:8000"


def get_visits():
    r = requests.get(f"{SERVER_URL}/all_visits")
    answ = r.json()
    return answ

# %%
visits = get_visits()
print(f"visits: {visits}")
# Out:
# visits: [{'id_animal': 21, 'pet_name': 'Kropka', 'breed': 'border collie', 'sex': 'samica', 'age': 2, 'coat': 'czarny, podpalany', 'weight': 16, 'interview_description': 'w załączniku przesyłam wyniki badania krwi Kropy. Są one bardzo dobre, wykluczyły podejrzenie niedoczynności trzustki (TLI w normie). W morfologii brak cech anemii i stanu zapalnego. Jedynie lekko podwyższony poziom eozynofilii ale przy tak niskim poziomie jest to mało diagnostyczne, może być związane nawet z chwilową reakcja alergiczną.  \nW biochemii wydolność nerek, wątroby prawidłowa. Poziom głównych białek, elektrolitów oraz glukozy także prawidłowa. \nPoziom wit B12 i kw. foliowego jest w tzw. szarej strefie i na chwilę obecna nie ma koniecnzości suplementacji. \nMyślę, że to co możemy zrobić to na okres kilku tygodni wdrożyć pastę z gastro maślanem oraz żywe kultury bakterii tak aby wzmocnić barierę jelitową i poprawić mikrobiom jelit. ', 'treatment_description': '<5 ng/ml – wysokie prawdopodobieństwo zewnątrzwydzielniczej niewydolności trzustki.\n5-15 ng/ml - zakres wątpliwy. W dalszej diagnostyce zaleca się oznaczenie elastazy trzustkowej w kale.\n15-50 ng/ml - zakres prawidłowy. Zewnątrzwydzielnicza niewydolność trzustki może być w znacznej mierze\nwykluczona.\n>50 ng/ml - wynik podwyższony. Przy odpowiednim obrazie klinicznym może wskazywać na zapalenie trzustki.\nNależy jednak pamiętać o niskiej swoistości tego badania w rozpoznawaniu pancreatitis (podwyższone wyniki\nnotuje się również m.in. w przebiegu niewydolności nerek lub zapaleń jelit). W dalszym postępowaniu zaleca\nsię wykorzystać diagnostykę obrazową i/lub wykonać oznaczenie lipazy DGGR/cPL.\nUwagi:\nWartości stężenia TLI są wiarygodne jedynie po min. 12-godzinnej głodówce i w surowicy niewykazującej śladów\nhemolizy.\nSuplementacja enzymów trzustkowych nie ma wpływu na wynik badania. Podwyższone stężenie wit. B12 może wskazywać na procesy immunoproliferacyjne lub być efektem jej zwiększonej\nsuplementacji w diecie. Jednocześnie występuje podejrzenie schorzenia proksymalnej części jelita cienkiego\n(dwunastnicy, j. czczego) wraz z zaburzeniem wchłaniania. Wykluczyć należy niedobory żywieniowe kwasu\nfoliowego.', 'applied_medicines': ' pasta z gastro maślanem oraz żywe kultury bakterii', 'recommendation': 'Myślę, że to co możemy zrobić to na okres kilku tygodni wdrożyć pastę z gastro maślanem oraz żywe kultury bakterii tak aby wzmocnić barierę jelitową i poprawić mikrobiom jelit. ', 'visit_time': '2025-11-29T16:11:49.576497', 'owner_name': 'Magdalena Nowak', 'species': 'pies', 'id_visit': 19}, {'id_animal': 21, 'pet_name': 'Kropka', 'breed': 'border collie', 'sex': 'samica', 'age': 2, 'coat': 'czarny, podpalany', 'weight': 16, 'interview_description': 'Wykryto obecność jednokomórkowego pierwotniaka jelitowego Cryptosporidium sp. \n', 'treatment_description': 'Pasożyty w kale\nWynik badania: UJEMNY; w badanym materiale nie\nstwierdzono obecności form\ndyspersyjnych pasożytów jelitowych', 'applied_medicines': None, 'recommendation': 'Jeden z gatunków - C. parvum - w sprzyjających warunkach może zarazić człowieka, dlatego zalecam zintensyfikowanie higieny kontaktów z psem, nie mamy na niego dostępnej metody leczenia a infestacja powinna być zazwyczaj zwalczona spontanicznie przez sprawny układ odpornościowy psa. Przy bardzo dużym namnożeniu może wywoływać biegunki - wskazane jest wtedy leczenie objawowe. Jednocześnie warto rozważyć suplementację probiotykiem zawierającym szczepy grzybów drożdżopodobnych np. Flora defense i to na dłuższy okres np. 4-6 tygodni, ponieważ grzyby te powinny konkurować o tę samą niszę ekologiczną i wypierać pasożyta.', 'visit_time': '2025-11-29T16:08:37.510364', 'owner_name': 'Magdalena Nowak', 'species': 'pies', 'id_visit': 18}, {'id_animal': 17, 'pet_name': 'Franio', 'breed': '', 'sex': 'samiec', 'age': None, 'coat': 'brązowy', 'weight': 0.05, 'interview_description': 'Chomik trafił do gabinetu z powodu nagłej apatii i zmniejszonego apetytu, zauważonych przez wł ...

# %%
len(visits)
# Out:
# 19

# %%
visits[0].keys()
# Out:
# dict_keys(['id_animal', 'pet_name', 'breed', 'sex', 'age', 'coat', 'weight', 'interview_description', 'treatment_description', 'applied_medicines', 'recommendation', 'visit_time', 'owner_name', 'species', 'id_visit'])

# %%
import faiss
import numpy as np
from openai import OpenAI

# %%
import os
from dotenv import load_dotenv
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
OPENAI_API_KEY
# Out:
# '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'

# %%
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
def get_embedding(text):
    response = client.embeddings.create(
    model="text-embedding-3-small",
    input=text
    )

    return np.array(response.data[0].embedding, dtype=np.float32)

# %%
from tqdm import tqdm
embedding_list = []
id_to_visit = []

# input:
# "interview_description": "opis wizyty...",
# "treatment_description": "badanie...",
# output:
# "applied_medicines"
#  {visit['recommendation']}

def get_visit_text(visit):
    visit_text = f"{visit['interview_description']} {visit['treatment_description']}"
    return visit_text

for visit in tqdm(visits):
    visit_text = get_visit_text(visit) 
    emb = get_embedding(visit_text)
    embedding_list.append(emb)
    id_to_visit.append(visit['id_visit'])
# Out:
# 100%|██████████| 19/19 [00:06<00:00,  2.83it/s]

# %%
embeddings_array = np.vstack(embedding_list)
dimension = embeddings_array.shape[1]
index = faiss.IndexFlatL2(dimension)
index.add(embeddings_array)

print(f"Added {len(embeddings_array)} vectors.")
# Out:
# Added 19 vectors.

# %%
index_file_name = "vet_visits.index"
faiss.write_index(index, index_file_name)
print(f"Saved in '{index_file_name}'")
# Out:
# Saved in 'vet_visits.index'

# %%
import pickle
id_file_name = "id_to_visit.pkl"
with open(id_file_name, "wb") as f:
    pickle.dump(id_to_visit, f)

# %% [markdown]
# # Read

# %%
loaded_index = faiss.read_index(index_file_name)
with open(id_file_name, "rb") as f:
    loaded_id_to_visit = pickle.load(f)

# %%
from pypdf import PdfReader

PDF_PATH = "../data/Walker.pdf"


def read_pdf(path):
    reader = PdfReader(path)
    text = ""
    for page in reader.pages:
        text += page.extract_text() + "\n"
    return text

# %%
pdf_text = read_pdf(PDF_PATH)
pdf_text

test_dict = {
    "interview_description": "Dziś pierwszy raz napady drgawkowe z niecałkowitą utratą przytomności, pierwszy o godzinie 18:20. W trakcie ataku pies otwierał szeroko oczy i głęboko oddychał, pomiędzy atakami całkowita utrata przytomności, nie oddał ani kału ani moczu. Każdy z ataków trwał około 30-40 sekund. Do godziny 21:00 około 7 ataków. Ostatni posiłek jadł rano, ma stały dostęp do karmy. Pies nie ma dostępu do trucizn ani nawozów, mieszka w kojcu, dziś rano jadł standardowe jedzenie. Około miesiąc temu przebył babeszjozę potwierdzoną w gabinecie weterynaryjnym, otrzymał dwie kroplówki dożylne, nie kontynuowano leczenia. Wcześniej nie wykazywał niepokojących objawów. Jest psem adoptowanym, właściciele nie znają jego wcześniejszych losów, w schronisku nie miał ataków, wcześniej silne zapalenie płuc. Zaszczepiony przeciwko wściekliźnie i chorobom wirusowym. Pies jest agresywny. Dziś przywieziony nieprzytomny, mokry, właścicielka schładzała polewając wodą.",
    "treatment_description": "Podłączono psa do maski tlenowej, założono wkłucie dożylne, pobrano krew na szeroki profil z jonogramem, podano Płyn Ringera 600 ml w tempie 400 ml/h, w trakcie ataku podano propofol 4,5 ml i.v., następnie dodatkowo 1 ml propofolu i.v. Odbyły się badania laboratoryjne (krew, T4, fT4), monitorowano parametry życiowe. Przygotowano psa do wyjazdu do lecznicy całodobowej na monitoring.",
    "applied_medicines": "Propofol-Lipuro 10mg/1ml 5,5 ml, Płyn Ringera 600 ml",
    "recommendation": "Nocny monitoring w lecznicy całodobowej, diagnostyka w celu wykluczenia zaburzeń kardiologicznych oraz pełne badanie neurologiczne po odzyskaniu przez psa przytomności. Oczekiwanie na wynik oznaczenia hormonów tarczycy. Kontakt w tej sprawie z lecznicą."
}

# %%
def find_in_vector_db(interview_description, treatment_description, k):
    # Tworzymy embedding dla zapytania
    query_text = f"{interview_description}  {treatment_description}"
    query_vector = get_embedding(query_text).reshape(1, -1)

    # Wyszukujemy najbliższe przypadki w bazie FAISS
    distances, indices = loaded_index.search(query_vector, k=k)
    return distances, indices

# %%
interview_description = test_dict["interview_description"]
treatment_description = test_dict["treatment_description"]
k = 3

# %%
distances, indices = find_in_vector_db(interview_description, treatment_description, k)
distances, indices
# Out:
# (array([[0.18627787, 0.36045304, 0.39317876]], dtype=float32),
#  array([[18,  5,  3]]))

# %%
def get_similar_visits_info(indices, visits):
    # Zbieramy leki i zalecenia z najbliższych wizyt
    similar_visits_info = []
    for idx in indices[0]:
        visit_id = loaded_id_to_visit[idx]
        visit = next(v for v in visits if v['id_visit'] == visit_id)
        similar_visits_info.append({
            "applied_medicines": visit['applied_medicines'],
            "recommendation": visit['recommendation']
        })
    return similar_visits_info

# %%
similar_visits_info = get_similar_visits_info(indices, visits)
similar_visits_info
# Out:
# [{'applied_medicines': None, 'recommendation': None},
#  {'applied_medicines': None, 'recommendation': None},
#  {'applied_medicines': None, 'recommendation': None}]

# %%
similar_visits_info = []
for idx in indices[0]:
    visit_id = loaded_id_to_visit[idx]
    visit = next(v for v in visits if v['id_visit'] == visit_id)
    print(idx, visit_id, visit['applied_medicines'], visit['recommendation'])
    similar_visits_info.append({
        "applied_medicines": visit['applied_medicines'],
        "recommendation": visit['recommendation']
    })
# Out:
# 18 1 None None
# 5 14 None None
# 3 16 None None

# %%
def generate_prompt_for_new_visit(interview_description, treatment_description, k=3):
    """
    Generuje prompt dla nowej wizyty na podstawie podobnych przypadków w bazie.

    ```
    Parametry:
    - interview_description: tekst wywiadu pacjenta
    - treatment_description: opis leczenia
    - k: liczba najbliższych przypadków do uwzględnienia
    """
    distances, indices = find_in_vector_db(interview_description, treatment_description, k)

    similar_visits_info = get_similar_visits_info(indices, visits)


    # Tworzymy prompt dla LLM z informacjami o podobnych przypadkach
    prompt = f"Nowa wizyta:\nWywiad: {interview_description}\nLeczenie: {treatment_description}\n\nPodobne przypadki i ich zalecenia:\n"
    for i, info in enumerate(similar_visits_info, 1):
        prompt += f"{i}. Leki: {info['applied_medicines']}, Zalecenia: {info['recommendation']}\n"

    prompt += "\nNa podstawie tych przykładów, wygeneruj zalecenia i przepisz leki dla nowej wizyty."

    return prompt

# %%
prompt = generate_prompt_for_new_visit(interview_description, treatment_description, k)
print(prompt)
# Out:
# Nowa wizyta:
# Wywiad: Dziś pierwszy raz napady drgawkowe z niecałkowitą utratą przytomności, pierwszy o godzinie 18:20. W trakcie ataku pies otwierał szeroko oczy i głęboko oddychał, pomiędzy atakami całkowita utrata przytomności, nie oddał ani kału ani moczu. Każdy z ataków trwał około 30-40 sekund. Do godziny 21:00 około 7 ataków. Ostatni posiłek jadł rano, ma stały dostęp do karmy. Pies nie ma dostępu do trucizn ani nawozów, mieszka w kojcu, dziś rano jadł standardowe jedzenie. Około miesiąc temu przebył babeszjozę potwierdzoną w gabinecie weterynaryjnym, otrzymał dwie kroplówki dożylne, nie kontynuowano leczenia. Wcześniej nie wykazywał niepokojących objawów. Jest psem adoptowanym, właściciele nie znają jego wcześniejszych losów, w schronisku nie miał ataków, wcześniej silne zapalenie płuc. Zaszczepiony przeciwko wściekliźnie i chorobom wirusowym. Pies jest agresywny. Dziś przywieziony nieprzytomny, mokry, właścicielka schładzała polewając wodą.
# Leczenie: Podłączono psa do maski tlenowej, założono wkłucie dożylne, pobrano krew na szeroki profil z jonogramem, podano Płyn Ringera 600 ml w tempie 400 ml/h, w trakcie ataku podano propofol 4,5 ml i.v., następnie dodatkowo 1 ml propofolu i.v. Odbyły się badania laboratoryjne (krew, T4, fT4), monitorowano parametry życiowe. Przygotowano psa do wyjazdu do lecznicy całodobowej na monitoring.
#
# Podobne przypadki i ich zalecenia:
# 1. Leki: None, Zalecenia: None
# 2. Leki: None, Zalecenia: None
# 3. Leki: None, Zalecenia: None
#
# Na podstawie tych przykładów, wygeneruj zalecenia i przepisz leki dla nowej wizyty.

# %%
test_dict["treatment_description"]
# Out:
# 'Podłączono psa do maski tlenowej, założono wkłucie dożylne, pobrano krew na szeroki profil z jonogramem, podano Płyn Ringera 600 ml w tempie 400 ml/h, w trakcie ataku podano propofol 4,5 ml i.v., następnie dodatkowo 1 ml propofolu i.v. Odbyły się badania laboratoryjne (krew, T4, fT4), monitorowano parametry życiowe. Przygotowano psa do wyjazdu do lecznicy całodobowej na monitoring.'

# %%
query_vector = embeddings[0:1]

# %%
distances, indices = loaded_index.search(query_vector, k=3)

for idx, dist in zip(indices[0], distances[0]):
    print(f"id_visit: {loaded_id_to_visit[idx]}, distance: {dist}")
# Out:
# id_visit: 19, distance: 0.0
# id_visit: 18, distance: 0.8718173503875732
# id_visit: 2, distance: 0.9155937433242798
